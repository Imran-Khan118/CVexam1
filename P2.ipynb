# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
# Load the image in grayscale
image_path = '/content/PrivateTest_2390435.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Parameters for brightness and contrast enhancement
alpha = 1.5  # Contrast control (1.0-3.0)
beta = 50    # Brightness control (0-100)

# Apply brightness and contrast enhancement
enhanced_image = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Display the enhanced image
plt.imshow(enhanced_image, cmap='gray')
plt.title('Enhanced Image (Brightness and Contrast)')
plt.axis('off')
plt.show()

# %% [markdown]
# # Task 3

# %%
# Apply Canny edge detection
edges = cv2.Canny(enhanced_image, threshold1=50, threshold2=150)

# Display the edge-detected image
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection (Canny)')
plt.axis('off')
plt.show()

# %% [markdown]
# # Task 4

# %%
# Apply Gaussian blur to soften non-essential features
blurred_image = cv2.GaussianBlur(enhanced_image, (3, 3), 0)

# Display the blurred image
plt.imshow(blurred_image, cmap='gray')
plt.title('Blurred Image (Gaussian)')
plt.axis('off')
plt.show()
